# %% [markdown]
# ## 1. 학습 진행

# %%
import os
from typing import Callable
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.td3.policies import MlpPolicy
from stable_baselines3.common.env_util import make_vec_env 
import matplotlib.pyplot as plt
#from gsde import gSDE

# Set LD_LIBRARY_PATH environment variable
os.environ['LD_LIBRARY_PATH'] = '/usr/lib/nvidia:/usr/lib/x86_64-linux-gnu:/usr/local/cuda/lib64:/home/jovyan/.mujoco/mujoco210/bin'

# %%
import numpy as np
from stable_baselines3.common.callbacks import BaseCallback

class TrainingRecorderCallback(BaseCallback):
    def __init__(self, verbose=0):
        super(TrainingRecorderCallback, self).__init__(verbose)
        self.training_rewards = []
        self.training_observations = []
        self.training_actions = []

    def _on_step(self) -> bool:
        self.training_rewards.append(self.locals["rewards"])
        self.training_observations.append(self.locals["new_obs"]) 
        self.training_actions.append(self.locals["actions"])
        return True  # Keep training

# %%
env_id = "Humanoid-v4"  # Specify the environment
n_envs = 8
n_steps = 1024
env = make_vec_env(env_id, n_envs=n_envs)  # Create vectorized environment (optional, but recommended for efficiency)

def linear_schedule(initial_value: float) -> Callable[[float], float]:
    """
    Linear learning rate decay schedule.
    :param initial_value: (float)
    :return: (function)
    """
    def func(progress_remaining: float) -> float:
        """
        Progress will decrease from 1 (beginning) to 0
        :param progress_remaining: (float)
        :return: (float)
        """
        return progress_remaining * initial_value

    return func


model = PPO("MlpPolicy", env, learning_rate=linear_schedule(0.001), 
            n_steps=n_steps, verbose=1, 
            use_sde=True,batch_size=n_steps*n_envs//4, n_epochs=2000, 
            gamma=0.95, gae_lambda=0.9, tensorboard_log="./PPO_Humanoid_tensorboard/")

# training_rewards = []  
# training_observations = []
# training_actions = []

model.learn(total_timesteps=500000, callback = TrainingRecorderCallback())
model.save("ppo_humanoid")
# Out:
# Import error. Trying to rebuild mujoco_py.
# running build_ext
# building 'mujoco_py.cymj' extension
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -Ixrl/lib/python3.8/site-packages/mujoco_py -I/home/jovyan/xrl_with_trajectories/xrl/lib/python3.8/site-packages/mujoco_py -I/home/jovyan/.mujoco/mujoco210/include -I/home/jovyan/xrl_with_trajectories/xrl/lib/python3.8/site-packages/numpy/core/include -I/home/jovyan/xrl_with_trajectories/xrl/include -I/usr/include/python3.8 -c /home/jovyan/xrl_with_trajectories/xrl/lib/python3.8/site-packages/mujoco_py/cymj.c -o /home/jovyan/xrl_with_trajectories/xrl/lib/python3.8/site-packages/mujoco_py/generated/_pyxbld_2.1.2.14_38_linuxcpuextensionbuilder/temp.linux-x86_64-3.8/home/jovyan/xrl_with_trajectories/xrl/lib/python3.8/site-packages/mujoco_py/cymj.o -fopenmp -w
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -Ixrl/lib/python3.8/site-packages/mujoco_py -I/home/jovyan/xrl_with_trajectories/xrl/lib/python3.8/site-packages/mujoco_py -I/home/jovyan/.mujoco/mujoco210/include -I/home/jovyan/xrl_with_trajectories/xrl/lib/python3.8/site-packages/numpy/core/include -I/home/jovyan/xrl_with_trajectories/xrl/include -I/usr/include/python3.8 -c /home/jovyan/xrl_with_trajectories/xrl/lib/python3.8/site-packages/mujoco_py/gl/osmesashim.c -o /home/jovyan/xrl_with_trajectories/xrl/lib/python3.8/site-packages/mujoco_py/generated/_pyxbld_2.1.2.14_38_linuxcpuextensionbuilder/temp.linux-x86_64-3.8/home/jovyan/xrl_with_trajectories/xrl/lib/python3.8/site-packages/mujoco_py/gl/osmesashim.o -fopenmp -w
# x86_64-linux-gnu-gcc -pthread -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -Wl,-z,relro -g -fwrapv -O2 -Wl,-Bsymbolic-functions -Wl,-z,relro -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 /home/jovyan/xrl_with_trajectories/xrl/lib/python3.8/site-packages/mujoco_py/generated/_pyxbld_2.1.2.14_38_linuxcpuextensionbuilder/temp.linux-x86_64-3.8/home/jovyan/xrl_with_trajectories/xrl/lib/python3.8/site-packages/mujoco_py/cymj.o /home/jovyan/xrl_with_trajectories/xrl/lib/python3.8/site-packages/mujoco_py/generated/_pyxbld_2.1.2.14_38_linuxcpuextensionbuilder/temp.linux-x86_64-3.8/home/jovyan/xrl_with_trajectories/xrl/lib/python3.8/site-packages/mujoco_py/gl/osmesashim.o -L/home/jovyan/.mujoco/mujoco210/bin -Wl,--enable-new-dtags,-R/home/jovyan/.mujoco/mujoco210/bin -lmujoco210 -lglewosmesa -lOSMesa -lGL -o /home/jovyan/xrl_with_trajectories/xrl/lib/python3.8/site-packages/mujoco_py/generated/_pyxbld_2.1.2.14_38_linuxcpuextensionbuilder/lib.linux-x86_64-3.8/mujoco_py/cymj.cpython-38-x86_64-linux-gnu.so -fopenmp
# Using cuda device
# Logging to ./PPO_Humanoid_tensorboard/PPO_23
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.7     |
# |    ep_rew_mean     | 108      |
# | time/              |          |
# |    fps             | 1917     |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 8192     |
# ---------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 19.4      |
# |    ep_rew_mean          | 92.8      |
# | time/                   |           |
# |    fps                  | 371       |
# |    iterations           | 2         |
# |    time_elapsed         | 44        |
# |    total_timesteps      | 16384     |
# | train/                  |           |
# |    approx_kl            | 0.4956871 |
# |    clip_fraction        | 0.939     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -53       |
# |    explained_variance   | -0.00553  |
# |    learning_rate        | 0.000984  |
# |    loss                 | 0.591     |
# |    n_updates            | 2000      |
# |    policy_gradient_loss | -0.154    |
# |    std                  | 0.912     |
# |    value_loss           | 10.5      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 24.8       |
# |    ep_rew_mean          | 120        |
# | time/                   |            |
# |    fps                  | 289        |
# |    iterations           | 3          |
# |    time_elapsed         | 84         |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.22120795 |
# |    clip_fraction        | 0.916      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -52.5      |
# |    explained_variance   | 0.514      |
# |    learning_rate        | 0.000967   |
# |    loss                 | 1.29       |
# |    n_updates            | 4000       |
# |    policy_gradient_loss | -0.15      |
# |    std                  | 0.883      |
# |    value_loss           | 5.31       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 22.4       |
# |    ep_rew_mean          | 108        |
# | time/                   |            |
# |    fps                  | 261        |
# |    iterations           | 4          |
# |    time_elapsed         | 125        |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.13959222 |
# |    clip_fraction        | 0.84       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -52.3      |
# |    explained_variance   | 0.586      |
# |    learning_rate        | 0.000951   |
# |    loss                 | 3.42       |
# |    n_updates            | 6000       |
# |    policy_gradient_loss | -0.141     |
# |    std                  | 0.867      |
# |    value_loss           | 13.3       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.7        |
# |    ep_rew_mean          | 113         |
# | time/                   |             |
# |    fps                  | 247         |
# |    iterations           | 5           |
# |    time_elapsed         | 165         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.117251545 |
# |    clip_fraction        | 0.804       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -52.1       |
# |    explained_variance   | 0.701       |
# |    learning_rate        | 0.000934    |
# |    loss                 | 3.89        |
# |    n_updates            | 8000        |
# |    policy_gradient_loss | -0.139      |
# |    std                  | 0.856       |
# |    value_loss           | 13.6        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 29.8       |
# |    ep_rew_mean          | 142        |
# | time/                   |            |
# |    fps                  | 237        |
# |    iterations           | 6          |
# |    time_elapsed         | 206        |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.10188251 |
# |    clip_fraction        | 0.763      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -52        |
# |    explained_variance   | 0.654      |
# |    learning_rate        | 0.000918   |
# |    loss                 | 4.56       |
# |    n_updates            | 10000      |
# |    policy_gradient_loss | -0.136     |
# |    std                  | 0.85       |
# |    value_loss           | 16.5       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30.3        |
# |    ep_rew_mean          | 148         |
# | time/                   |             |
# |    fps                  | 231         |
# |    iterations           | 7           |
# |    time_elapsed         | 247         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.115296856 |
# |    clip_fraction        | 0.749       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -52         |
# |    explained_variance   | 0.562       |
# |    learning_rate        | 0.000902    |
# |    loss                 | 6.17        |
# |    n_updates            | 12000       |
# |    policy_gradient_loss | -0.134      |
# |    std                  | 0.844       |
# |    value_loss           | 22          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.5        |
# |    ep_rew_mean          | 138         |
# | time/                   |             |
# |    fps                  | 227         |
# |    iterations           | 8           |
# |    time_elapsed         | 288         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.105076894 |
# |    clip_fraction        | 0.723       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -51.9       |
# |    explained_variance   | 0.638       |
# |    learning_rate        | 0.000885    |
# |    loss                 | 6.03        |
# |    n_updates            | 14000       |
# |    policy_gradient_loss | -0.131      |
# |    std                  | 0.839       |
# |    value_loss           | 21          |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 33.6       |
# |    ep_rew_mean          | 166        |
# | time/                   |            |
# |    fps                  | 224        |
# |    iterations           | 9          |
# |    time_elapsed         | 329        |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.09565808 |
# |    clip_fraction        | 0.711      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -51.7      |
# |    explained_variance   | 0.612      |
# |    learning_rate        | 0.000869   |
# |    loss                 | 7.14       |
# |    n_updates            | 16000      |
# |    policy_gradient_loss | -0.129     |
# |    std                  | 0.832      |
# |    value_loss           | 22.5       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 35         |
# |    ep_rew_mean          | 170        |
# | time/                   |            |
# |    fps                  | 221        |
# |    iterations           | 10         |
# |    time_elapsed         | 369        |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.09059503 |
# |    clip_fraction        | 0.674      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -51.7      |
# |    explained_variance   | 0.585      |
# |    learning_rate        | 0.000853   |
# |    loss                 | 7.99       |
# |    n_updates            | 18000      |
# |    policy_gradient_loss | -0.127     |
# |    std                  | 0.826      |
# |    value_loss           | 27.7       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 27.9       |
# |    ep_rew_mean          | 137        |
# | time/                   |            |
# |    fps                  | 219        |
# |    iterations           | 11         |
# |    time_elapsed         | 411        |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.08651501 |
# |    clip_fraction        | 0.627      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -51.6      |
# |    explained_variance   | 0.638      |
# |    learning_rate        | 0.000836   |
# |    loss                 | 10.1       |
# |    n_updates            | 20000      |
# |    policy_gradient_loss | -0.122     |
# |    std                  | 0.822      |
# |    value_loss           | 32.8       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 33.9       |
# |    ep_rew_mean          | 167        |
# | time/                   |            |
# |    fps                  | 217        |
# |    iterations           | 12         |
# |    time_elapsed         | 452        |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.09218386 |
# |    clip_fraction        | 0.66       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -51.5      |
# |    explained_variance   | 0.603      |
# |    learning_rate        | 0.00082    |
# |    loss                 | 10.7       |
# |    n_updates            | 22000      |
# |    policy_gradient_loss | -0.126     |
# |    std                  | 0.818      |
# |    value_loss           | 32.2       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 33.5       |
# |    ep_rew_mean          | 166        |
# | time/                   |            |
# |    fps                  | 215        |
# |    iterations           | 13         |
# |    time_elapsed         | 493        |
# |    total_timesteps      | 106496     |
# | train/                  |            |
# |    approx_kl            | 0.09434387 |
# |    clip_fraction        | 0.682      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -51.5      |
# |    explained_variance   | 0.533      |
# |    learning_rate        | 0.000803   |
# |    loss                 | 12         |
# |    n_updates            | 24000      |
# |    policy_gradient_loss | -0.129     |
# |    std                  | 0.813      |
# |    value_loss           | 29.9       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 36.1       |
# |    ep_rew_mean          | 178        |
# | time/                   |            |
# |    fps                  | 214        |
# |    iterations           | 14         |
# |    time_elapsed         | 534        |
# |    total_timesteps      | 114688     |
# | train/                  |            |
# |    approx_kl            | 0.10030708 |
# |    clip_fraction        | 0.68       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -51.3      |
# |    explained_variance   | 0.636      |
# |    learning_rate        | 0.000787   |
# |    loss                 | 9.62       |
# |    n_updates            | 26000      |
# |    policy_gradient_loss | -0.128     |
# |    std                  | 0.809      |
# |    value_loss           | 29.2       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 40.2       |
# |    ep_rew_mean          | 194        |
# | time/                   |            |
# |    fps                  | 213        |
# |    iterations           | 15         |
# |    time_elapsed         | 574        |
# |    total_timesteps      | 122880     |
# | train/                  |            |
# |    approx_kl            | 0.08048662 |
# |    clip_fraction        | 0.608      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -51.3      |
# |    explained_variance   | 0.657      |
# |    learning_rate        | 0.000771   |
# |    loss                 | 12.5       |
# |    n_updates            | 28000      |
# |    policy_gradient_loss | -0.119     |
# |    std                  | 0.806      |
# |    value_loss           | 36.7       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 44.9       |
# |    ep_rew_mean          | 224        |
# | time/                   |            |
# |    fps                  | 213        |
# |    iterations           | 16         |
# |    time_elapsed         | 615        |
# |    total_timesteps      | 131072     |
# | train/                  |            |
# |    approx_kl            | 0.10010493 |
# |    clip_fraction        | 0.643      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -51.2      |
# |    explained_variance   | 0.603      |
# |    learning_rate        | 0.000754   |
# |    loss                 | 8.13       |
# |    n_updates            | 30000      |
# |    policy_gradient_loss | -0.121     |
# |    std                  | 0.804      |
# |    value_loss           | 30         |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 40.9        |
# |    ep_rew_mean          | 203         |
# | time/                   |             |
# |    fps                  | 212         |
# |    iterations           | 17          |
# |    time_elapsed         | 656         |
# |    total_timesteps      | 139264      |
# | train/                  |             |
# |    approx_kl            | 0.092529476 |
# |    clip_fraction        | 0.631       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -51.2       |
# |    explained_variance   | 0.627       |
# |    learning_rate        | 0.000738    |
# |    loss                 | 9.98        |
# |    n_updates            | 32000       |
# |    policy_gradient_loss | -0.121      |
# |    std                  | 0.801       |
# |    value_loss           | 32.7        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 43.7       |
# |    ep_rew_mean          | 214        |
# | time/                   |            |
# |    fps                  | 211        |
# |    iterations           | 18         |
# |    time_elapsed         | 697        |
# |    total_timesteps      | 147456     |
# | train/                  |            |
# |    approx_kl            | 0.08556083 |
# |    clip_fraction        | 0.644      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -51.1      |
# |    explained_variance   | 0.698      |
# |    learning_rate        | 0.000721   |
# |    loss                 | 13.7       |
# |    n_updates            | 34000      |
# |    policy_gradient_loss | -0.123     |
# |    std                  | 0.798      |
# |    value_loss           | 31.3       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38          |
# |    ep_rew_mean          | 185         |
# | time/                   |             |
# |    fps                  | 210         |
# |    iterations           | 19          |
# |    time_elapsed         | 738         |
# |    total_timesteps      | 155648      |
# | train/                  |             |
# |    approx_kl            | 0.091340356 |
# |    clip_fraction        | 0.613       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -51         |
# |    explained_variance   | 0.662       |
# |    learning_rate        | 0.000705    |
# |    loss                 | 10.9        |
# |    n_updates            | 36000       |
# |    policy_gradient_loss | -0.117      |
# |    std                  | 0.796       |
# |    value_loss           | 33          |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 42.3      |
# |    ep_rew_mean          | 212       |
# | time/                   |           |
# |    fps                  | 210       |
# |    iterations           | 20        |
# |    time_elapsed         | 779       |
# |    total_timesteps      | 163840    |
# | train/                  |           |
# |    approx_kl            | 0.0844249 |
# |    clip_fraction        | 0.615     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -51       |
# |    explained_variance   | 0.668     |
# |    learning_rate        | 0.000689  |
# |    loss                 | 13.1      |
# |    n_updates            | 38000     |
# |    policy_gradient_loss | -0.117    |
# |    std                  | 0.793     |
# |    value_loss           | 39.2      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 42.6       |
# |    ep_rew_mean          | 213        |
# | time/                   |            |
# |    fps                  | 209        |
# |    iterations           | 21         |
# |    time_elapsed         | 820        |
# |    total_timesteps      | 172032     |
# | train/                  |            |
# |    approx_kl            | 0.08948319 |
# |    clip_fraction        | 0.613      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -50.9      |
# |    explained_variance   | 0.612      |
# |    learning_rate        | 0.000672   |
# |    loss                 | 12.2       |
# |    n_updates            | 40000      |
# |    policy_gradient_loss | -0.116     |
# |    std                  | 0.789      |
# |    value_loss           | 40.9       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 47.4       |
# |    ep_rew_mean          | 234        |
# | time/                   |            |
# |    fps                  | 209        |
# |    iterations           | 22         |
# |    time_elapsed         | 861        |
# |    total_timesteps      | 180224     |
# | train/                  |            |
# |    approx_kl            | 0.08485408 |
# |    clip_fraction        | 0.614      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -50.9      |
# |    explained_variance   | 0.72       |
# |    learning_rate        | 0.000656   |
# |    loss                 | 13.8       |
# |    n_updates            | 42000      |
# |    policy_gradient_loss | -0.118     |
# |    std                  | 0.787      |
# |    value_loss           | 37.5       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 40.1       |
# |    ep_rew_mean          | 196        |
# | time/                   |            |
# |    fps                  | 208        |
# |    iterations           | 23         |
# |    time_elapsed         | 902        |
# |    total_timesteps      | 188416     |
# | train/                  |            |
# |    approx_kl            | 0.08787363 |
# |    clip_fraction        | 0.608      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -50.8      |
# |    explained_variance   | 0.707      |
# |    learning_rate        | 0.00064    |
# |    loss                 | 12.3       |
# |    n_updates            | 44000      |
# |    policy_gradient_loss | -0.118     |
# |    std                  | 0.784      |
# |    value_loss           | 36.5       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 48.2       |
# |    ep_rew_mean          | 239        |
# | time/                   |            |
# |    fps                  | 208        |
# |    iterations           | 24         |
# |    time_elapsed         | 943        |
# |    total_timesteps      | 196608     |
# | train/                  |            |
# |    approx_kl            | 0.08875429 |
# |    clip_fraction        | 0.607      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -50.8      |
# |    explained_variance   | 0.741      |
# |    learning_rate        | 0.000623   |
# |    loss                 | 11.4       |
# |    n_updates            | 46000      |
# |    policy_gradient_loss | -0.118     |
# |    std                  | 0.782      |
# |    value_loss           | 33.4       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 45         |
# |    ep_rew_mean          | 225        |
# | time/                   |            |
# |    fps                  | 208        |
# |    iterations           | 25         |
# |    time_elapsed         | 984        |
# |    total_timesteps      | 204800     |
# | train/                  |            |
# |    approx_kl            | 0.08237854 |
# |    clip_fraction        | 0.579      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -50.8      |
# |    explained_variance   | 0.759      |
# |    learning_rate        | 0.000607   |
# |    loss                 | 11.3       |
# |    n_updates            | 48000      |
# |    policy_gradient_loss | -0.114     |
# |    std                  | 0.779      |
# |    value_loss           | 33.5       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 43.6       |
# |    ep_rew_mean          | 218        |
# | time/                   |            |
# |    fps                  | 207        |
# |    iterations           | 26         |
# |    time_elapsed         | 1024       |
# |    total_timesteps      | 212992     |
# | train/                  |            |
# |    approx_kl            | 0.09085935 |
# |    clip_fraction        | 0.616      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -50.7      |
# |    explained_variance   | 0.769      |
# |    learning_rate        | 0.00059    |
# |    loss                 | 12.1       |
# |    n_updates            | 50000      |
# |    policy_gradient_loss | -0.116     |
# |    std                  | 0.775      |
# |    value_loss           | 32.8       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 52         |
# |    ep_rew_mean          | 263        |
# | time/                   |            |
# |    fps                  | 207        |
# |    iterations           | 27         |
# |    time_elapsed         | 1065       |
# |    total_timesteps      | 221184     |
# | train/                  |            |
# |    approx_kl            | 0.09083058 |
# |    clip_fraction        | 0.623      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -50.6      |
# |    explained_variance   | 0.731      |
# |    learning_rate        | 0.000574   |
# |    loss                 | 13.2       |
# |    n_updates            | 52000      |
# |    policy_gradient_loss | -0.119     |
# |    std                  | 0.772      |
# |    value_loss           | 37.1       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48.6        |
# |    ep_rew_mean          | 243         |
# | time/                   |             |
# |    fps                  | 207         |
# |    iterations           | 28          |
# |    time_elapsed         | 1106        |
# |    total_timesteps      | 229376      |
# | train/                  |             |
# |    approx_kl            | 0.095367506 |
# |    clip_fraction        | 0.604       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -50.6       |
# |    explained_variance   | 0.723       |
# |    learning_rate        | 0.000558    |
# |    loss                 | 11.1        |
# |    n_updates            | 54000       |
# |    policy_gradient_loss | -0.116      |
# |    std                  | 0.769       |
# |    value_loss           | 31.7        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 52.7       |
# |    ep_rew_mean          | 265        |
# | time/                   |            |
# |    fps                  | 206        |
# |    iterations           | 29         |
# |    time_elapsed         | 1148       |
# |    total_timesteps      | 237568     |
# | train/                  |            |
# |    approx_kl            | 0.09069549 |
# |    clip_fraction        | 0.612      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -50.5      |
# |    explained_variance   | 0.758      |
# |    learning_rate        | 0.000541   |
# |    loss                 | 10.5       |
# |    n_updates            | 56000      |
# |    policy_gradient_loss | -0.117     |
# |    std                  | 0.767      |
# |    value_loss           | 32         |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50.4        |
# |    ep_rew_mean          | 253         |
# | time/                   |             |
# |    fps                  | 206         |
# |    iterations           | 30          |
# |    time_elapsed         | 1188        |
# |    total_timesteps      | 245760      |
# | train/                  |             |
# |    approx_kl            | 0.085486725 |
# |    clip_fraction        | 0.57        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -50.4       |
# |    explained_variance   | 0.793       |
# |    learning_rate        | 0.000525    |
# |    loss                 | 12.2        |
# |    n_updates            | 58000       |
# |    policy_gradient_loss | -0.111      |
# |    std                  | 0.765       |
# |    value_loss           | 30.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 51.5        |
# |    ep_rew_mean          | 258         |
# | time/                   |             |
# |    fps                  | 206         |
# |    iterations           | 31          |
# |    time_elapsed         | 1229        |
# |    total_timesteps      | 253952      |
# | train/                  |             |
# |    approx_kl            | 0.084021166 |
# |    clip_fraction        | 0.561       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -50.4       |
# |    explained_variance   | 0.785       |
# |    learning_rate        | 0.000508    |
# |    loss                 | 14.8        |
# |    n_updates            | 60000       |
# |    policy_gradient_loss | -0.109      |
# |    std                  | 0.763       |
# |    value_loss           | 34.5        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 54        |
# |    ep_rew_mean          | 267       |
# | time/                   |           |
# |    fps                  | 206       |
# |    iterations           | 32        |
# |    time_elapsed         | 1270      |
# |    total_timesteps      | 262144    |
# | train/                  |           |
# |    approx_kl            | 0.0848224 |
# |    clip_fraction        | 0.58      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -50.4     |
# |    explained_variance   | 0.774     |
# |    learning_rate        | 0.000492  |
# |    loss                 | 11.1      |
# |    n_updates            | 62000     |
# |    policy_gradient_loss | -0.111    |
# |    std                  | 0.761     |
# |    value_loss           | 31        |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 52         |
# |    ep_rew_mean          | 257        |
# | time/                   |            |
# |    fps                  | 206        |
# |    iterations           | 33         |
# |    time_elapsed         | 1311       |
# |    total_timesteps      | 270336     |
# | train/                  |            |
# |    approx_kl            | 0.08837575 |
# |    clip_fraction        | 0.578      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -50.3      |
# |    explained_variance   | 0.806      |
# |    learning_rate        | 0.000476   |
# |    loss                 | 11.7       |
# |    n_updates            | 64000      |
# |    policy_gradient_loss | -0.111     |
# |    std                  | 0.759      |
# |    value_loss           | 32.1       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 57.9       |
# |    ep_rew_mean          | 292        |
# | time/                   |            |
# |    fps                  | 205        |
# |    iterations           | 34         |
# |    time_elapsed         | 1352       |
# |    total_timesteps      | 278528     |
# | train/                  |            |
# |    approx_kl            | 0.08738141 |
# |    clip_fraction        | 0.6        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -50.3      |
# |    explained_variance   | 0.783      |
# |    learning_rate        | 0.000459   |
# |    loss                 | 13.9       |
# |    n_updates            | 66000      |
# |    policy_gradient_loss | -0.115     |
# |    std                  | 0.756      |
# |    value_loss           | 35         |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 59.5       |
# |    ep_rew_mean          | 302        |
# | time/                   |            |
# |    fps                  | 205        |
# |    iterations           | 35         |
# |    time_elapsed         | 1392       |
# |    total_timesteps      | 286720     |
# | train/                  |            |
# |    approx_kl            | 0.08824767 |
# |    clip_fraction        | 0.549      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -50.2      |
# |    explained_variance   | 0.815      |
# |    learning_rate        | 0.000443   |
# |    loss                 | 10.3       |
# |    n_updates            | 68000      |
# |    policy_gradient_loss | -0.108     |
# |    std                  | 0.753      |
# |    value_loss           | 29.5       |
# ----------------------------------------

# %%
del model  # Remove old model
model = PPO.load("ppo_humanoid")

obs = env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    env.render("human")

# %%
import matplotlib.pyplot as plt

# Assuming you have rewards, observations, and actions in dedicated lists
plt.plot(rewards)
plt.xlabel("Training Step")
plt.ylabel("Reward")
plt.title("Reward Progress")
plt.show()
